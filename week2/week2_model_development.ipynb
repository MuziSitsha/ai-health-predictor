# %% [markdown]
# # Week 2: Model Development
# ## AI Health Predictor Project
#
# This notebook contains model development work from Week 2.
# See the run_simple_models.py script for the actual implementation.

# %%
# Model development summary
print("Week 2 Model Development Summary")
print("="*40)
print("\nModels trained:")
print("1. Logistic Regression")
print("2. Random Forest")
print("3. Gradient Boosting")
print("4. SVM")
print("\nBest Model: Random Forest")
print("Accuracy: 75.97%")
print("\nAll models saved in week2/models/")
print("Reports saved in week2/reports/")

# %%
# Check model files
import os

print("Model files created:")
model_files = os.listdir('week2/models')
for file in model_files:
    print(f"  - {file}")
